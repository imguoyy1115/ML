# %% [markdown]
# <a href="https://colab.research.google.com/github/imguoyy1115/ML/blob/main/gcn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 安装Miniconda（tensorflow1.15.0与当前版本不兼容），创建Python3.7环境

# %%
# 下载并安装Miniconda
# !wget https://repo.anaconda.com/miniconda/Miniconda3-py37_4.10.3-Linux-x86_64.sh
# !bash Miniconda3-py37_4.10.3-Linux-x86_64.sh -b -p /content/Miniconda3

import os
os.environ['PATH'] = "/content/miniconda3/bin:" + os.environ['PATH']
# Out:
# --2026-05-07 11:59:05--  https://repo.anaconda.com/miniconda/Miniconda3-py37_4.10.3-Linux-x86_64.sh
# Resolving repo.anaconda.com (repo.anaconda.com)... 104.16.191.158, 104.16.32.241, 2606:4700::6810:bf9e, ...
# Connecting to repo.anaconda.com (repo.anaconda.com)|104.16.191.158|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 89026327 (85M) [application/x-sh]
# Saving to: ‘Miniconda3-py37_4.10.3-Linux-x86_64.sh’
#
# Miniconda3-py37_4.1 100%[===================>]  84.90M   203MB/s    in 0.4s
#
# 2026-05-07 11:59:05 (203 MB/s) - ‘Miniconda3-py37_4.10.3-Linux-x86_64.sh’ saved [89026327/89026327]
#
# PREFIX=/content/Miniconda3
# Unpacking payload ...
# done
# done
#
# ## Package Plan ##
#
#   environment location: /content/Miniconda3
#
#   added / updated specs:
#     - _libgcc_mutex==0.1=main
#     - _openmp_mutex==4.5=1_gnu
#     - brotlipy==0.7.0=py37h27cfd23_1003
#     - ca-certificates==2021.7.5=h06a4308_1
#     - certifi==2021.5.30=py37h06a4308_0
# ...

# %%
# 把Conda的路径加入环境变量
import os
os.environ['PATH'] = "/content/Miniconda3/bin:" + os.environ['PATH']

# %%
# 创建名为tf1的Python3.7环境
# !conda create -n tf1 python=3.7 -y
# Out:
# done
# failed with repodata from current_repodata.json, will retry with next repodata source.
# done
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.10.3
#   latest version: 26.3.2
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# ## Package Plan ##
#
#   environment location: /content/Miniconda3/envs/tf1
#
#   added / updated specs:
#     - python=3.7
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     _openmp_mutex-5.1          |            1_gnu          21 KB
#     ca-certificates-2026.3.19  |       h06a4308_0         126 KB
#     certifi-2022.12.7          |   py37h06a4308_0         150 KB
#     ld_impl_linux-64-2.44      |       h9e0c5a2_3         725 KB
#     libffi-3.4.8               |       hc5d346e_2         136 KB
#     libgcc-15.2.0              |       h69a1729_7         806 KB
# ...

# %% [markdown]
# 安装相关库和TensorFlow

# %%
# 安装所需库
# !conda run -n tf1 pip install protobuf==3.20.3
# !conda run -n tf1 pip install networkx
# !conda run -n tf1 pip install scipy==1.4.1

# 安装tensorflow
# !conda run -n tf1 pip install tensorflow==1.15.0
# !conda run -n tf1 python -c "import tensorflow as tf; print(tf.__version__)"
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 29.1 MB/s eta 0:00:00
# ...
#
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 40.7 MB/s eta 0:00:00
# ...
#
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 26.1/26.1 MB 55.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.7/15.7 MB 74.6 MB/s eta 0:00:00
# ...
#
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 412.3/412.3 MB 4.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.7/133.7 kB 17.2 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.7/50.7 kB 4.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 503.4/503.4 kB 23.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 84.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.5/57.5 kB 7.2 MB/s eta 0:00:00
# ...

# %% [markdown]
# 克隆github并运行
# https://github.com/imguoyy1115/gcn

# %%
# 克隆仓库
# !git clone https://github.com/imguoyy1115/gcn
# Out:
# Cloning into 'gcn'...
# remote: Enumerating objects: 169, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Compressing objects: 100% (3/3), done.
# remote: Total 169 (delta 0), reused 0 (delta 0), pack-reused 166 (from 1)
# Receiving objects: 100% (169/169), 5.10 MiB | 24.05 MiB/s, done.
# Resolving deltas: 100% (82/82), done.

# %%
# 安装GCN项目库
# %cd /content/gcn
# !conda run -n tf1 python setup.py install
# Out:
# /content/gcn
# ERROR conda.cli.main_run:execute(34): Subprocess for 'conda run ['python', 'setup.py', 'install']' command failed.  (See above for error)
# running install
# running bdist_egg
# running egg_info
# writing gcn.egg-info/PKG-INFO
# writing dependency_links to gcn.egg-info/dependency_links.txt
# writing requirements to gcn.egg-info/requires.txt
# writing top-level names to gcn.egg-info/top_level.txt
# reading manifest file 'gcn.egg-info/SOURCES.txt'
# adding license file 'LICENCE'
# writing manifest file 'gcn.egg-info/SOURCES.txt'
# installing library code to build/bdist.linux-x86_64/egg
# running install_lib
# running build_py
# creating build/bdist.linux-x86_64/egg
# creating build/bdist.linux-x86_64/egg/gcn
# copying build/lib/gcn/models.py -> build/bdist.linux-x86_64/egg/gcn
# copying build/lib/gcn/metrics.py -> build/bdist.linux-x86_64/egg/gcn
# copying build/lib/gcn/utils.py -> build/bdist.linux-x86_64/egg/gcn
# ...

# %%
# 运行训练代码
# %cd /content/gcn/gcn
# !conda run -n tf1 python train.py
# Out:
# /content/gcn/gcn
# Epoch: 0001 train_loss= 1.95334 train_acc= 0.10000 val_loss= 1.95048 val_acc= 0.16400 time= 0.14080
# Epoch: 0002 train_loss= 1.94804 train_acc= 0.27857 val_loss= 1.94673 val_acc= 0.37000 time= 0.02405
# Epoch: 0003 train_loss= 1.94225 train_acc= 0.45714 val_loss= 1.94266 val_acc= 0.47400 time= 0.02658
# Epoch: 0004 train_loss= 1.93542 train_acc= 0.57857 val_loss= 1.93844 val_acc= 0.51600 time= 0.01826
# Epoch: 0005 train_loss= 1.92587 train_acc= 0.67857 val_loss= 1.93415 val_acc= 0.52400 time= 0.01776
# Epoch: 0006 train_loss= 1.91736 train_acc= 0.63571 val_loss= 1.92997 val_acc= 0.51400 time= 0.01789
# Epoch: 0007 train_loss= 1.91078 train_acc= 0.65000 val_loss= 1.92593 val_acc= 0.48600 time= 0.01744
# Epoch: 0008 train_loss= 1.90264 train_acc= 0.63571 val_loss= 1.92185 val_acc= 0.48800 time= 0.01822
# Epoch: 0009 train_loss= 1.89481 train_acc= 0.63571 val_loss= 1.91780 val_acc= 0.48200 time= 0.01799
# ...
